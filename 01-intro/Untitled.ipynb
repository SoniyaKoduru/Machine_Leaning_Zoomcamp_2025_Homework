# %%
import pandas as pd

# %%
df = pd.read_csv('https://raw.githubusercontent.com/alexeygrigorev/datasets/master/car_fuel_efficiency.csv')
df.head()
# Out:
#    engine_displacement  num_cylinders  horsepower  vehicle_weight  \
# 0                  170            3.0       159.0     3413.433759
# 1                  130            5.0        97.0     3149.664934
# 2                  170            NaN        78.0     3079.038997
# 3                  220            4.0         NaN     2542.392402
# 4                  210            1.0       140.0     3460.870990
#
#    acceleration  model_year  origin fuel_type         drivetrain  num_doors  \
# 0          17.7        2003  Europe  Gasoline    All-wheel drive        0.0
# 1          17.8        2007     USA  Gasoline  Front-wheel drive        0.0
# 2          15.1        2018  Europe  Gasoline  Front-wheel drive        0.0
# 3          20.2        2009     USA    Diesel    All-wheel drive        2.0
# 4          14.4        2009  Europe  Gasoline    All-wheel drive        2.0
#
#    fuel_efficiency_mpg
# 0            13.231729
# 1            13.688217
# 2            14.246341
# 3            16.912736
# 4            12.488369

# %%
pd.__version__
# Out:
# '2.3.1'

# %%
df.tail()
# Out:
#       engine_displacement  num_cylinders  horsepower  vehicle_weight  \
# 9699                  140            5.0       164.0     2981.107371
# 9700                  180            NaN       154.0     2439.525729
# 9701                  220            2.0       138.0     2583.471318
# 9702                  230            4.0       177.0     2905.527390
# 9703                  270            3.0       140.0     2908.043477
#
#       acceleration  model_year  origin fuel_type         drivetrain  \
# 9699          17.3        2013  Europe    Diesel  Front-wheel drive
# 9700          15.0        2004     USA  Gasoline    All-wheel drive
# 9701          15.1        2008     USA    Diesel    All-wheel drive
# 9702          19.4        2011     USA    Diesel  Front-wheel drive
# 9703          14.7        2005    Asia    Diesel    All-wheel drive
#
#       num_doors  fuel_efficiency_mpg
# 9699        NaN            15.101802
# 9700        0.0            17.962326
# 9701       -1.0            17.186587
# 9702        1.0            15.331551
# 9703       -1.0            14.884467

# %%
df['fuel_type'].unique()
# Out:
# array(['Gasoline', 'Diesel'], dtype=object)

# %%
df.isna().sum()
# Out:
# engine_displacement      0
# num_cylinders          482
# horsepower             708
# vehicle_weight           0
# acceleration           930
# model_year               0
# origin                   0
# fuel_type                0
# drivetrain               0
# num_doors              502
# fuel_efficiency_mpg      0
# dtype: int64

# %%
df.dropna().head()
# Out:
#    engine_displacement  num_cylinders  horsepower  vehicle_weight  \
# 0                  170            3.0       159.0     3413.433759
# 1                  130            5.0        97.0     3149.664934
# 4                  210            1.0       140.0     3460.870990
# 6                  240            7.0       127.0     3006.542287
# 7                  150            4.0       239.0     3638.657780
#
#    acceleration  model_year  origin fuel_type         drivetrain  num_doors  \
# 0          17.7        2003  Europe  Gasoline    All-wheel drive        0.0
# 1          17.8        2007     USA  Gasoline  Front-wheel drive        0.0
# 4          14.4        2009  Europe  Gasoline    All-wheel drive        2.0
# 6          22.2        2012     USA  Gasoline  Front-wheel drive        1.0
# 7          17.3        2020     USA    Diesel    All-wheel drive        1.0
#
#    fuel_efficiency_mpg
# 0            13.231729
# 1            13.688217
# 4            12.488369
# 6            13.210412
# 7            12.848884

# %%
df1 = df.dropna()

# %%
df1.isna().sum()
# Out:
# engine_displacement    0
# num_cylinders          0
# horsepower             0
# vehicle_weight         0
# acceleration           0
# model_year             0
# origin                 0
# fuel_type              0
# drivetrain             0
# num_doors              0
# fuel_efficiency_mpg    0
# dtype: int64

# %%
df1['fuel_efficiency_mpg'].max()
# Out:
# np.float64(25.96722204888372)

# %%
df1.describe()
# Out:
#        engine_displacement  num_cylinders   horsepower  vehicle_weight  \
# count           7333.00000    7333.000000  7333.000000     7333.000000
# mean             199.62771       3.970680   149.783308     3004.449983
# std               49.17886       2.010159    30.036236      499.098552
# min               30.00000       0.000000    37.000000      952.681761
# 25%              170.00000       3.000000   130.000000     2668.613340
# 50%              200.00000       4.000000   150.000000     2996.645087
# 75%              230.00000       5.000000   170.000000     3337.746684
# max              380.00000      13.000000   271.000000     4726.977269
#
#        acceleration   model_year    num_doors  fuel_efficiency_mpg
# count   7333.000000  7333.000000  7333.000000          7333.000000
# mean      15.034611  2011.510705    -0.010910            14.972735
# std        2.515208     6.618722     1.046461             2.560661
# min        6.000000  2000.000000    -4.000000             6.200971
# 25%       13.300000  2006.000000    -1.000000            13.254933
# 50%       15.100000  2012.000000     0.000000            15.009360
# 75%       16.700000  2017.000000     1.000000            16.696031
# max       24.300000  2023.000000     4.000000            25.967222
